# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %%
chipo
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
# 5         3  ...     $10.98
# 6         3  ...      $1.69
# 7         4  ...     $11.75
# 8         4  ...      $9.25
# 9         5  ...      $9.25
#
# [10 rows x 5 columns]

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
chipo.groupby('item_name').sum().loc[:, 'quantity'].sort_values(ascending = False).iloc[:5].plot(kind = 'bar')

plt.title('top 5 items bought')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
chipo['item_price'] = chipo['item_price'].apply(extract_value)
chipo['item_price'] = chipo['item_price'].astype(float)
chipo
# Out:
#       order_id  ...  item_price
# 0            1  ...        2.39
# 1            1  ...        3.39
# 2            1  ...        3.39
# 3            1  ...        2.39
# 4            2  ...       16.98
# ...        ...  ...         ...
# 4617      1833  ...       11.75
# 4618      1833  ...       11.75
# 4619      1834  ...       11.25
# 4620      1834  ...        8.75
# 4621      1834  ...        8.75
#
# [4622 rows x 5 columns]

# %%
X_axis = chipo.groupby('order_id').sum()['item_price']
Y_axis = chipo.groupby('order_id').sum()['quantity']

plt.scatter(X_axis, Y_axis)
plt.xlabel('item price')
plt.ylabel('number of ordered items')
plt.show()

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.
