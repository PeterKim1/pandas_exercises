# %% [markdown]
# # Regiment

# %% [markdown]
# ### Introduction:
#
# Special thanks to: http://chrisalbon.com/ for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create the DataFrame with the following values:

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %% [markdown]
# ### Step 3. Assign it to a variable called regiment.
# #### Don't forget to name each column

# %%
regiment = pd.DataFrame(raw_data, columns = raw_data.keys())

# %%
regiment.head()
# Out:
#   company    regiment      name  postTestScore  preTestScore
# 0     1st  Nighthawks    Miller             25             4
# 1     1st  Nighthawks  Jacobson             94            24
# 2     2nd  Nighthawks       Ali             57            31
# 3     2nd  Nighthawks    Milner             62             2
# 4     1st    Dragoons     Cooze             70             3

# %% [markdown]
# ### Step 4. What is the mean preTestScore from the regiment Nighthawks?

# %%
regiment[regiment['regiment'] == 'Nighthawks']['preTestScore'].mean()
# Out:
# 15.25

# %% [markdown]
# ### Step 5. Present general statistics by company

# %%
regiment.groupby('company').describe()
# Out:
#         postTestScore                                                       \
#                 count       mean        std   min    25%   50%   75%   max
# company
# 1st               6.0  57.666667  27.485754  25.0  34.25  66.0  70.0  94.0
# 2nd               6.0  67.000000  14.057027  57.0  58.25  62.0  68.0  94.0
#
#         preTestScore
#                count       mean        std  min   25%   50%    75%   max
# company
# 1st              6.0   6.666667   8.524475  2.0  3.00   3.5   4.00  24.0
# 2nd              6.0  15.500000  14.652645  2.0  2.25  13.5  29.25  31.0

# %% [markdown]
# ### Step 6. What is the mean of each company's preTestScore?

# %%
regiment.groupby('company').preTestScore.mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 7. Present the mean preTestScores grouped by regiment and company

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %% [markdown]
# ### Step 8. Present the mean preTestScores grouped by regiment and company without heirarchical indexing

# %%
regiment.groupby(['regiment', 'company']).preTestScore.mean().unstack()
# Out:
# company      1st   2nd
# regiment
# Dragoons     3.5  27.5
# Nighthawks  14.0  16.5
# Scouts       2.5   2.5

# %%
regiment.groupby(['regiment', 'company'], as_index = False).preTestScore.mean()
# Out:
#      regiment company  preTestScore
# 0    Dragoons     1st           3.5
# 1    Dragoons     2nd          27.5
# 2  Nighthawks     1st          14.0
# 3  Nighthawks     2nd          16.5
# 4      Scouts     1st           2.5
# 5      Scouts     2nd           2.5

# %% [markdown]
# ### Step 9. Group the entire dataframe by regiment and company

# %%
regiment.groupby(['regiment', 'company']).loc[:, :] # DataFrameGroupBy object에는 loc 사용 불가.
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-19-ef76ed375db9> in <module>()
# ----> 1 regiment.groupby(['regiment', 'company']).loc[:, :]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby/groupby.pyc in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby/groupby.pyc in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
#     572         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'loc' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
regiment.groupby(['regiment', 'company']).apply(lambda x: x.loc[:, :])
# Out:
#    company      name  postTestScore  preTestScore    regiment
# 0      1st    Miller             25             4  Nighthawks
# 1      1st  Jacobson             94            24  Nighthawks
# 2      2nd       Ali             57            31  Nighthawks
# 3      2nd    Milner             62             2  Nighthawks
# 4      1st     Cooze             70             3    Dragoons
# 5      1st     Jacon             25             4    Dragoons
# 6      2nd    Ryaner             94            24    Dragoons
# 7      2nd      Sone             57            31    Dragoons
# 8      1st     Sloan             62             2      Scouts
# 9      1st     Piger             70             3      Scouts
# 10     2nd     Riani             62             2      Scouts
# 11     2nd       Ali             70             3      Scouts

# %% [markdown]
# ### Step 10. What is the number of observations in each regiment and company

# %%
regiment.groupby(['regiment', 'company']).size()
# Out:
# regiment    company
# Dragoons    1st        2
#             2nd        2
# Nighthawks  1st        2
#             2nd        2
# Scouts      1st        2
#             2nd        2
# dtype: int64

# %% [markdown]
# ### Step 11. Iterate over a group and print the name and the whole data from the regiment

# %%
for name, group in regiment.groupby('regiment'):
    print(name) 
    print(group)
# Out:
# Dragoons
#   company  regiment    name  postTestScore  preTestScore
# 4     1st  Dragoons   Cooze             70             3
# 5     1st  Dragoons   Jacon             25             4
# 6     2nd  Dragoons  Ryaner             94            24
# 7     2nd  Dragoons    Sone             57            31
# Nighthawks
#   company    regiment      name  postTestScore  preTestScore
# 0     1st  Nighthawks    Miller             25             4
# 1     1st  Nighthawks  Jacobson             94            24
# 2     2nd  Nighthawks       Ali             57            31
# 3     2nd  Nighthawks    Milner             62             2
# Scouts
#    company regiment   name  postTestScore  preTestScore
# 8      1st   Scouts  Sloan             62             2
# 9      1st   Scouts  Piger             70             3
# 10     2nd   Scouts  Riani             62             2
# 11     2nd   Scouts    Ali             70             3
